# %%
# Mengubah nilai elemen didalam list

#membuat list 
negara = ['Zimbabwe','Jepang','Swiss','Australia','Canada']
print ("sebelum diubah :")
print (negara)
# mengubah nilai elemen list 
negara [1] = 'Lebanon' 

#menampilkan hasil perubahan 
print ('Setelah Diubah :')
print (negara)

# membuat list 
negara = ['Zimbabwe','Jepang','Swiss','Australia','Canada']
print('sebelum dihapus')
print(negara)
negara.remove('Jepang')

print('setelah diapus')
print(negara)

#menggunakan metode dell[]; menghapus elemen list berdasarkan indeksnya
#bentuk umum dell nama_variabel[indeks]
del negara[-2]
print ('setelah negara dihapus dengan del')
print (negara)

#menggunakan metode clear[]; menghapus semua elemen list
print('setelah di clear menggunakan dengan metode clear')
negara.clear()
print(negara)

#membuat list dengan mencari elemen menggunakan metode index()
#membuat list 
negara = ['Zimbabwe','Jepang','Swiss','Australia','Canada']
print(negara)
#mencari elemen list 
#bentuk_umum : nama_variabel.index('nilai atau elemen yang akan diindex')
print('Swiss berada diindex ke-')
print(negara.index('Swiss'))

# menyusun data dalama list menggunakan metode sort() dan reverse()
# membuat list 
negara = ['Zimbabwe','Jepang','Swiss','Australia','Canada']
# menggunakan metode sort()
print('Data list awal (sort)  :')
print(negara)
print('Setelah di sort :')
negara.sort()
print(negara)

#menggunakan metode reverse()
print('Data list awal (reverse) :')
print(negara)
print('Setelah di reverse :')
negara.reverse()
print(negara)

# membuat list karakter dalam sebuah string 
# membuat list 
negara = ['Zimbabwe','Jepang','Swiss','Australia','Canada']
print(list)
print ('Data negara:')
print(negara)
print('mengulang karakter pada item Australia sebanyak dua kali :')
doubles = [c*2 for c in 'Australia']
print(doubles)
# Out:
# sebelum diubah :
# ['Zimbabwe', 'Jepang', 'Swiss', 'Australia', 'Canada']
# Setelah Diubah :
# ['Zimbabwe', 'Lebanon', 'Swiss', 'Australia', 'Canada']
# sebelum dihapus
# ['Zimbabwe', 'Jepang', 'Swiss', 'Australia', 'Canada']
# setelah diapus
# ['Zimbabwe', 'Swiss', 'Australia', 'Canada']
# setelah negara dihapus dengan del
# ['Zimbabwe', 'Swiss', 'Canada']
# setelah di clear menggunakan dengan metode clear
# []
# ['Zimbabwe', 'Jepang', 'Swiss', 'Australia', 'Canada']
# Swiss berada diindex ke-
# 2
# Data list awal (sort)  :
# ['Zimbabwe', 'Jepang', 'Swiss', 'Australia', 'Canada']
# Setelah di sort :
# ['Australia', 'Canada', 'Jepang', 'Swiss', 'Zimbabwe']
# Data list awal (reverse) :
# ['Australia', 'Canada', 'Jepang', 'Swiss', 'Zimbabwe']
# Setelah di reverse :
# ['Zimbabwe', 'Swiss', 'Jepang', 'Canada', 'Australia']
# <class 'list'>
# Data negara:
# ['Zimbabwe', 'Jepang', 'Swiss', 'Australia', 'Canada']
# mengulang karakter pada item Australia sebanyak dua kali :
# ...
