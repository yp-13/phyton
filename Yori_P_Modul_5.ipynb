# %%
s = set([20,40,60,80])
print(s)
# Out:
# {40, 80, 20, 60}

# %%
fs = frozenset([5,10,15])
print(fs)
# Out:
# frozenset({10, 5, 15})

# %%
import sys

def printElements(s, info):
    print(info)
    if len(s) == 0:
        print("Himpunan kosong\n")
        sys.exit(1)
    for e in s:
        print(str(e) + " ", end = '')
    print("\n")

# membuat himpunan
s = set([100, 200, 300, 400, 500])
printElements(s, "Elemen awal:")

# menambah anggota/elemen baru
# menggunakan metode add()
s.add(66)
s.add(77)
printElements(s, "Setelah pemanggilan add():")

# menambah anggota/elemen baru
# menggunakan metode update()
s.update([88, 99])
printElements(s, "Setelah pemanggilan update():")

# menghapus elemen dengan nilai 44
s.remove(400)
printElements(s, "Setelah pemanggilan remove():")

# menghapus semua elemen
s.clear()
printElements(s, "Setelah pemanggilan clear():")
# Out:
# Elemen awal:
# 100 200 300 400 500
#
# Setelah pemanggilan add():
# 66 100 200 300 77 400 500
#
# Setelah pemanggilan update():
# 66 99 100 200 300 77 400 500 88
#
# Setelah pemanggilan remove():
# 66 99 100 200 300 77 500 88
#
# Setelah pemanggilan clear():
# Himpunan kosong
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit: 1

# %%
# Tipe set mendukung operasi-operasi himpunan seperti:

x = set([5, 10, 15])
y = set([3,9])

a = x | y  # union
print('Operasi union:')
print(a)

b = x & y  # intersection
print('Operasi intersection:')
print(b)

c = x - y  # difference
print('Operasi difference:')
print(c)

d = x ^ y  # symmetric difference
print('Operasi symmetric difference:')
print(d)
# Out:
# Operasi union:
# {3, 5, 9, 10, 15}
# Operasi intersection:
# set()
# Operasi difference:
# {10, 5, 15}
# Operasi symmetric difference:
# {3, 5, 9, 10, 15}

# %%
# Frozenset tidak memiliki metode add()
fs = frozenset ([10,20,30])
print(fs)
fs.add(40)
# Out:
# frozenset({10, 20, 30})
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[20], line 4
#       2 fs = frozenset ([10,20,30])
#       3 print(fs)
# ----> 4 fs.add(40)
#
# AttributeError: 'frozenset' object has no attribute 'add'

# %%
# Frozenset tidak memiliki metode update()
fs = frozenset ([10,20,30])
print(fs)
fs.update(40,50)
# Out:
# frozenset({10, 20, 30})
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[24], line 4
#       2 fs = frozenset ([10,20,30])
#       3 print(fs)
# ----> 4 fs.update(40,50)
#
# AttributeError: 'frozenset' object has no attribute 'update'

# %%
# Frozenset tidak memiliki metode clear()
fs = frozenset ([10,20,30])
print(fs)
fs.clear()
# Out:
# frozenset({10, 20, 30})
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[26], line 4
#       2 fs = frozenset ([10,20,30])
#       3 print(fs)
# ----> 4 fs.clear()
#
# AttributeError: 'frozenset' object has no attribute 'clear'

# %% [markdown]
#  # STRUKTUR PEMILIHAN

# %%
versi = 3
str = 'Pemograman Phyton'

if versi == 3:
    print (str + ' 3')
else: 
    print(str)
# Out:
# Pemograman Phyton 3

# %%
import sys
versi = sys.version

if versi[:1] == '3':
    print('Bahasa\t\t: Phyton 3')
    print('versi Pyhton\t:' + versi[:5])
# Out:
# Bahasa		: Phyton 3
# versi Pyhton	:3.12.

# %%
def main():
  x = float(input('Masukkan bilangan pertama\t:'))
  y = float(input('Masukkan bilangan kedua\t:'))
  op = input('Masukkan operator (+,-,*,/)\t:')
  if op == '+':
    print('%.2f + %.2f = %.2f' % (x, y, x+y))
  elif op == '-':
    print('%.2f - %.2f = %.2f' % (x, y, x-y))
  elif op == '*':
    print('%.2f * %.2f = %.2f' % (x, y, x*y))
  elif op == '/':
    print('%.2f / %.2f = %.2f' % (x, y, x/y))
  else:
    print('ERROR: Gunakan operator +,-,*,/')
if __name__ == '__main__':
  main()
# Out:
# Masukkan bilangan pertama	: 1034
# Masukkan bilangan kedua	: 273
# Masukkan operator (+,-,*,/)	: *
# 1034.00 * 273.00 = 282282.00

# %% [markdown]
#  # CONTOH PENGULANGAN

# %%
a = 'Phyton'
# Menelusuri Semua  Karakter dalam string: a
for c in a:
    print(c, end='')
# Out:
# Phyton

# %%
c = {'pergi' : 'go','hilang' : 'lost', 'lupakan':' forget'}
for key in c:
    print ("arti '%s' adalah '%s'" % (key, c[key]))
# Out:
# arti 'pergi' adalah 'go'
# arti 'hilang' adalah 'lost'
# arti 'lupakan' adalah ' forget'

# %%
b = ['phyton','ruby','per1','PHP']
# Menulusuri semua karakter didalam list : a
for e in b:
    print(e)
# Out:
# phyton
# ruby
# per1
# PHP

# %%
for i in range (10):
    print(i, end='')
# Out:
# 0123456789

# %%
for i in range (100,200,3):
    print("%d " % i, end ='')
# Out:
# 100 103 106 109 112 115 118 121 124 127 130 133 136 139 142 145 148 151 154 157 160 163 166 169 172 175 178 181 184 187 190 193 196 199
