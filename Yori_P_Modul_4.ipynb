# %% [markdown]
#  # TYPE OPERATOR

# %% [markdown]
#  # OPERATOR PENUGASAN

# %%
# Menggunakan tanda operasi / operator sama dengan (=)
a = 100
print(a)
# Out:
# 100

# %%
a = 100
a = a +200
print(a)
# Out:
# 300

# %%
a = 100
a += 200
print(a)
# Out:
# 300

# %%
b = 10
b *= 40
print(b)
# Out:
# 400

# %%
b = 10
b //= 40
print(b)
print(10/40)
# Out:
# 0
# 0.25

# %%
b = 10.0
b //= 40
print(b)
print(10/40)
# Out:
# 0.0
# 0.25

# %%
b = 10.0
b %= 40
print(b)
# Out:
# 10.0

# %% [markdown]
#  # TYPE ARITMATIKA

# %%
def main():
    #Mendefenisakan variable x dan y
    x = 10
    y = 5 
    
    # Menampilkan nilai x dan y
    print ('x =', x)
    print ('y =', y)
    
    # Melakukan perhitungan terhadap x dan y
    print('x + y', (x + y))
    print('x - y', (x - y))
    print('x * y', (x * y))
    print('x / y', (x / y))
    print('x // y', (x // y))
    print('x % y', (x % y))
    print('x ** y', (x ** y))

if __name__ == '__main__' :
   main()
# Out:
# x = 10
# y = 5
# x + y 15
# x - y 5
# x * y 50
# x / y 2.0
# x // y 2
# x % y 0
# x ** y 100000

# %% [markdown]
#  # OPERATOR RELASIONAL

# %%
def main():
    #Mendefenisakan variable x dan y
    x = 10
    y = 5
    li = [3,9,27,81,243]
    
    # Menampilkan nilai x dan y
    print ('x =', x)
    print ('y =', y)
    print (li)
    
    # Melakukan perhitungan terhadap x dan y
    print('x == y', (x == y))
    print('x != y', (x != y))
    print('x > y', (x > y))
    print('x >= y', (x >= y))
    print('x < y', (x < y))
    print('x <= y', (x <= y))
    print('x in li', (x in li))
    print('y in li', (y in li))


if __name__ == '__main__' :
   main()
# Out:
# x = 10
# y = 5
# [3, 9, 27, 81, 243]
# x == y False
# x != y True
# x > y True
# x >= y True
# x < y False
# x <= y False
# x in li False
# y in li False

# %% [markdown]
#  # OPERATOR LOGIKA

# %%
# CONTOH PROGRAM OPERASI AND 
def main(): 
    print('Operasi AND')
    print('True and True \t:', (True and True))
    print('True and False \t:', (True and False))
    print('False and True \t:', (False and True))
    print('True and False \t:', (True and False))

if __name__ == '__main__' :
   main()
# Out:
# Operasi AND
# True and True 	: True
# True and False 	: False
# False and True 	: False
# True and False 	: False

# %% [markdown]
#  # OPERASI STRING

# %%
str1 = 'Pulang'
str2 = 'Kampung'

# Menjumlah String 
str3 = (str1 + str2)
print(str3)
# Out:
# PulangKampung

# %%
bil1 = 100
bil2 = 200

print('bil1:' + str(bil1))
print('bil2:' + str(bil2))
# Out:
# bil1:100
# bil2:200

# %%
bil1 = 100
bil2 = 200

str1 = 'bil1 : %d' % bil1 
str2 = 'bil2 : %.2f' % bil2

print(str1)
print(str2)
# Out:
# bil1 : 100
# bil2 : 200.00

# %%
Pantai = 'Blue Lagoon'
if 'Eksotis' in Pantai :
    print ("'Eksotis' ada didalam string Pantai")
else :
    print ("'Eksotis' tidak ada didalam string Pantai")
# Out:
# 'Eksotis' tidak ada didalam string Pantai

# %%
karakter = 'k' 
teks = karakter * 5
print(teks)

print((teks +' ') * 5)
# Out:
# kkkkk
# kkkkk kkkkk kkkkk kkkkk kkkkk

# %%
print('Blue Lagoon' * 10)
# Out:
# Blue LagoonBlue LagoonBlue LagoonBlue LagoonBlue LagoonBlue LagoonBlue LagoonBlue LagoonBlue LagoonBlue Lagoon

# %% [markdown]
#  # OPERTOR BITWISE

# %%
def main():
    x = 500  # dalam bentuk biner: 01111000
    y = 127  # dalam bentuk biner: 01111111

    # menampilkan nilai x dan y
    print('x: \t' + str(x))
    print('y: \t' + str(y))

    print('\nBitwise AND')
    print('x & y \t: ' + str(x & y))

    print('\nBitwise OR')
    print('x | y \t: ' + str(x | y))

    print('\nBitwise XOR')
    print('x ^ y \t: ' + str(x ^ y))

    print('\nBitwise NOT')
    print('~x \t: ' + str(~x))
    print('~y \t: ' + str(~y))

    print('\nBitwise SHIFT LEFT')
    print('x << 1 \t: ' + str(x << 1))
    print('y << 1 \t: ' + str(y << 1))

    print('\nBitwise SHIFT RIGHT')
    print('x >> 1 \t: ' + str(x >> 1))
    print('y >> 1 \t: ' + str(y >> 1))

if __name__ == '__main__':
    main()
# Out:
# x: 	500
# y: 	127
#
# Bitwise AND
# x & y 	: 116
#
# Bitwise OR
# x | y 	: 511
#
# Bitwise XOR
# x ^ y 	: 395
#
# Bitwise NOT
# ~x 	: -501
# ~y 	: -128
#
# Bitwise SHIFT LEFT
# x << 1 	: 1000
# y << 1 	: 254
#
# Bitwise SHIFT RIGHT
# x >> 1 	: 250
# y >> 1 	: 63
